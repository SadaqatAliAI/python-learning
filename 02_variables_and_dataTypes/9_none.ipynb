# %% [markdown]
# ## ***None (`None`)***
# ---

# %% [markdown]
# - `None` represents the absence of a value and is an object of its own datatype.

# %%
result = None
# 'result' is assigned the special value None
# None represents "no value" or "empty" in Python

print(type(result))
# type() function tells the data type of 'result'
# Output: <class 'NoneType'>
